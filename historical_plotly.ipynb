# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv("/root/projects/BIA/Data/all_historical.csv")

# %%
df.head()
# Out:
#          Date           ANN     XGBoost          LSTM   Actual
# 0  2002-01-01  14491.580771  14563.2295  14552.500000  14552.5
# 1  2002-02-01  15618.681584  15196.7180  15260.799845  15260.8
# 2  2002-03-01  16528.107576  15584.8360  16485.299909  16485.3
# 3  2002-04-01  16642.862605  15990.2010  16681.099846  16681.1
# 4  2002-05-01  16341.909965  16256.8870  16293.100046  16293.1

# %%
# Using plotly.express
import plotly.express as px

#fig = px.line(df, x=df["Date"], y=df["Actual"])
fig = px.line(df, x=df["Date"], y=df["Actual"])
# fig.add_scatter(x=df["Date"], y=["XGBoost"])
# fig.add_scatter(x=df["Date"], y=["ANN"])
# fig.add_scatter(x=df["Date"], y=["LSTM"])
fig.show()
# Out:
# <div>                            <div id="771b6985-64ca-46e5-8973-cad359ca4960" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("771b6985-64ca-46e5-8973-cad359ca4960")) {                    Plotly.newPlot(                        "771b6985-64ca-46e5-8973-cad359ca4960",                        [{"hovertemplate":"Date=%{x}<br>Actual=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-
# ...

# %%
df.columns
# Out:
# Index(['Date', 'ANN', 'XGBoost', 'LSTM', 'Actual'], dtype='object')

# %%
import plotly.express as px

#df = px.data.gapminder().query("continent=='Oceania'")
fig = px.line(df, x="Date", y=['ANN', 'XGBoost', 'LSTM', 'Actual'])
fig.show()
# Out:
# <div>                            <div id="9c654ddd-0f42-4e6e-839e-7edf35427e50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c654ddd-0f42-4e6e-839e-7edf35427e50")) {                    Plotly.newPlot(                        "9c654ddd-0f42-4e6e-839e-7edf35427e50",                        [{"hovertemplate":"variable=ANN<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ANN","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ANN","showlegend":true,"x":["2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","200
# ...
